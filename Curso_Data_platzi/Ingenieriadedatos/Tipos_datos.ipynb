# %% [markdown]
# <h1>Primitivos</h1>

# %%
from datetime import datetime

integer_type = 24
float_type = 3.7
bool_type = False
hex_type= 0xff
oct_type= 0o23
today=datetime.now()
str_type="hola"

# %% [markdown]
# <h1>Estructurados</h1>

# %%
from IPython.display import Image

Image('mysql_table_example.png')

# %% [markdown]
# <h1>Solicitudes a la web</h1>

# %%
import requests

response=requests.get('https://www.platzi.com')

print(dir(response))
# Out:
# ['__attrs__', '__bool__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_content', '_content_consumed', '_next', 'apparent_encoding', 'close', 'connection', 'content', 'cookies', 'elapsed', 'encoding', 'headers', 'history', 'is_permanent_redirect', 'is_redirect', 'iter_content', 'iter_lines', 'json', 'links', 'next', 'ok', 'raise_for_status', 'raw', 'reason', 'request', 'status_code', 'text', 'url']

# %%
print(response.text)
# Out:
#     <!doctype html>
#       <html lang="es">
#         <head>
#
#           <meta name="viewport" content="width=device-width, initial-scale=1" />
#           <title>Cursos Online Profesionales de Tecnología | ‎🚀 Platzi</title>
#           <link rel="stylesheet" href="https://static.platzi.com/bff/assets/home.710cd1fdcd3a5b2f6ef8.css" type="text/css" />
#           <link rel="shortcut icon" href="//static.platzi.com/media/favicons/platzi_favicon.png" />
#           <link rel="icon" sizes="192x192" href="//static.platzi.com/media/favicons/platzi_favicon.png">
#           <link rel="alternate" type="application/rss+xml" title="RSS 2.0" href="" />
#           <meta name="description" content="Aprende desde cero a crear el futuro web con nuestros Cursos Online Profesionales de Tecnología. ¡Cursos Únicos de Desarrollo, Diseño, Marketing y Negocios!">
#           <meta name = "theme-color" content = "#15210B" />
#
#           <meta property="fb:app_id" content="263680607075199" />
# ...

# %% [markdown]
# <h1>Trabajando con documentos HTML</h1>

# %% [markdown]
# <p>BeautifulSoup nos ayuda a organizar gramaticalmente(parsear) el documento HTML para que tengamos una estructura con la cual podamos manejar y extraer información. BeautifulSoup convierte el string de HTML en un árbol de nodos para poder manipularlo.</p>

# %%
import bs4

soup = bs4.BeautifulSoup(response.text,'html.parser')

#print(soup.select('meta[name=description]')[0]['content'])

    
courses_links=soup.select('.HomeCategories-items > div.HomeCategories-item > a')
courses=[course['href'] for course in courses_links]

for course in courses:
    print(course)
# Out:
# /categorias/desarrollo/
# /categorias/negocios/
# /categorias/crecimiento-profesional/
# /categorias/produccion-audiovisual/
# /categorias/marketing/
# /categorias/diseno/

# %%
import bs4

soup = bs4.BeautifulSoup(response.text,'html.parser')

#print(soup.select('meta[name=description]')[0]['content'])

    
courses_links=soup.select('.CareerCourseItem-link')
courses=[course['href'] for course in courses_links]

for course in courses:
    print(course)
# Out:
# /cursos/taller-startups/
# /cursos/creacion-de-empresas/
# /cursos/ingles/
# /cursos/financiera-startups-2017/
# /cursos/developer/
# /cursos/internacionalizacion-startups/
# /cursos/ingles-basico/
# /cursos/ingles-gramatica/
# /cursos/ingles-conversacion/

# %%
response = requests.get('https://elpais.com/')
links = bs4.BeautifulSoup(response.text, 'html.parser')
new_list = [a['href'] for a in links.select('.articulo-titulo a')]

for print_links in new_list:
    print(print_links)
# Out:
# https://elpais.com/internacional/2019/11/21/colombia/1574344356_725900.html
# https://elpais.com/economia/2019/11/21/actualidad/1574358809_631322.html
# https://elpais.com/internacional/2019/11/21/actualidad/1574353973_200330.html
# https://elpais.com/internacional/2019/11/21/actualidad/1574360207_535959.html
# https://elpais.com/internacional/2019/11/21/estados_unidos/1574290890_096323.html
# https://elpais.com/economia/2019/11/21/actualidad/1574362402_506661.html
# https://elpais.com/economia/2019/11/20/actualidad/1574269489_495403.html
# https://elpais.com/internacional/2019/11/20/estados_unidos/1574286361_724260.html
# https://elpais.com/politica/2019/11/20/actualidad/1574276025_237776.html
# https://elpais.com/cultura/2019/11/20/television/1574273406_361603.html
# https://elpais.com/sociedad/2019/11/21/actualidad/1574324747_525988.html
# https://elpais.com/elpais/2019/11/21/ciencia/1574339197_870783.html
# ...

# %% [markdown]
# <h1>Series</h1>

# %%
import pandas as pd

series_test = pd.Series([100,200,300])

series_test
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
series_test2 = pd.Series({1999: 45,
                          2000: 65,
                          2001: 89})

series_test2
# Out:
# 1999    45
# 2000    65
# 2001    89
# dtype: int64

# %% [markdown]
# <h1>DataFrames</h1>

# %%
frame_test = pd.DataFrame({1999: [74,38,39],
                           2000: [34,32,32],
                           2001: [23,39,23]})

frame_test
# Out:
#    1999  2000  2001
# 0    74    34    23
# 1    38    32    39
# 2    39    32    23

# %%
frame_test2 = pd.DataFrame([[74,38,39],
                          [34,32,32],
                          [23,39,23]], columns=[1999,2000,2001])

frame_test2
# Out:
#    1999  2000  2001
# 0    74    38    39
# 1    34    32    32
# 2    23    39    23

# %% [markdown]
# <h1>Read Data</h1>

# %%
pd.options.display.max_rows = 10

el_universal = pd.read_csv('web_scrapper_curso_data_eng/eluniversal_2019_06_07_articles.csv')

el_universal
# Out:
#                                                   body  \
# 0    \nLa procuradora Ernestina Godoy confirmó que ...
# 1                                                  NaN
# 2                                                  NaN
# 3    \n\nTras el triunfo de Barbosa y la derrota de...
# 4    \n\nLa noticia de que las niñas y niños de la ...
# ..                                                 ...
# 194  \nCDMX.- Cerca de las 18:30 horas, un hombre d...
# 195  \nTexto: Aída Castro SánchezDiseño web: Miguel...
# 196  \nTingüindín, Michoacán.- Diego Vidal Manzo, s...
# 197                                                NaN
# 198                                                NaN
#
#                                                  title  \
# 0    Matan a exdiputado de Tláhuac; investigan vínc...
# 1                                                  NaN
# 2                                                  NaN
# 3    Puebla: un tropiezo electoral no es una derrot...
# ...

# %% [markdown]
# <h1>Index and selection</h1>

# %%
#dictionary like

el_universal['title']
# Out:
# 0      Matan a exdiputado de Tláhuac; investigan vínc...
# 1                                                    NaN
# 2                                                    NaN
# 3      Puebla: un tropiezo electoral no es una derrot...
# 4                              Entre faldas y pantalones
#                              ...
# 194    Policía auxilia a hombre de la tercera edad qu...
# 195    Las primeras reporteras que rompieron con los ...
# 196    Grupo armado ataca a subdirector de Seguridad ...
# 197                                                  NaN
# 198           Concacaf pide al Tri priorizar la Copa Oro
# Name: title, Length: 199, dtype: object

# %%
el_universal[['title','url']]
# Out:
#                                                  title  \
# 0    Matan a exdiputado de Tláhuac; investigan vínc...
# 1                                                  NaN
# 2                                                  NaN
# 3    Puebla: un tropiezo electoral no es una derrot...
# 4                            Entre faldas y pantalones
# ..                                                 ...
# 194  Policía auxilia a hombre de la tercera edad qu...
# 195  Las primeras reporteras que rompieron con los ...
# 196  Grupo armado ataca a subdirector de Seguridad ...
# 197                                                NaN
# 198         Concacaf pide al Tri priorizar la Copa Oro
#
#                                                    url
# 0    http://www.eluniversal.com.mx/metropoli/cdmx/m...
# 1           http://www.eluniversal.com.mx/deportes/box
# 2    https://www.tangible-eluniversal.com.mx/en-ver...
# 3    https://www.eluniversal.com.mx/articulo/maria-...
# ...

# %%
#numpy like

el_universal.iloc[10:15]
# Out:
#                                                  body  \
# 10                                                NaN
# 11                                                NaN
# 12  El año 2019 todavía es joven, pero un par de m...
# 13                                                NaN
# 14  La banda de rock Los Amigos Invisibles se pres...
#
#                                                 title  \
# 10                                                NaN
# 11                                 María Elena Morera
# 12                                                NaN
# 13                                       Andrew Selee
# 14  Los Amigos Invisibles en Naucalpan: Compra tus...
#
#                                                   url
# 10                             https://bit.ly/2jmdiXT
# 11  http://www.eluniversal.com.mx/autor-opinion/ar...
# 12  https://www.elgrafico.mx/espectaculos/ellas-so...
# 13  http://www.eluniversal.com.mx/autor-opinion/ar...
# ...

# %%
el_universal.iloc[66]['title']
# Out:
# 'Naasón “ha sido víctima de complot cibernético”, dice defensa'

# %%
el_universal.iloc[:5, 0]
# Out:
# 0    \nLa procuradora Ernestina Godoy confirmó que ...
# 1                                                  NaN
# 2                                                  NaN
# 3    \n\nTras el triunfo de Barbosa y la derrota de...
# 4    \n\nLa noticia de que las niñas y niños de la ...
# Name: body, dtype: object

# %%
el_universal.loc[:, 'body': 'title']
# Out:
#                                                   body  \
# 0    \nLa procuradora Ernestina Godoy confirmó que ...
# 1                                                  NaN
# 2                                                  NaN
# 3    \n\nTras el triunfo de Barbosa y la derrota de...
# 4    \n\nLa noticia de que las niñas y niños de la ...
# ..                                                 ...
# 194  \nCDMX.- Cerca de las 18:30 horas, un hombre d...
# 195  \nTexto: Aída Castro SánchezDiseño web: Miguel...
# 196  \nTingüindín, Michoacán.- Diego Vidal Manzo, s...
# 197                                                NaN
# 198                                                NaN
#
#                                                  title
# 0    Matan a exdiputado de Tláhuac; investigan vínc...
# 1                                                  NaN
# 2                                                  NaN
# 3    Puebla: un tropiezo electoral no es una derrot...
# ...

# %% [markdown]
# <h1>Data wrangling</h1>

# %%
# 1. añadir newspaper_uid al Daraframe

el_universal['newspaper_uid']= 'eluniversal'

el_universal
# Out:
#                                                   body  \
# 0    \nLa procuradora Ernestina Godoy confirmó que ...
# 1                                                  NaN
# 2                                                  NaN
# 3    \n\nTras el triunfo de Barbosa y la derrota de...
# 4    \n\nLa noticia de que las niñas y niños de la ...
# ..                                                 ...
# 194  \nCDMX.- Cerca de las 18:30 horas, un hombre d...
# 195  \nTexto: Aída Castro SánchezDiseño web: Miguel...
# 196  \nTingüindín, Michoacán.- Diego Vidal Manzo, s...
# 197                                                NaN
# 198                                                NaN
#
#                                                  title  \
# 0    Matan a exdiputado de Tláhuac; investigan vínc...
# 1                                                  NaN
# 2                                                  NaN
# 3    Puebla: un tropiezo electoral no es una derrot...
# ...

# %%
# 2. Obtener el host

from urllib.parse import urlparse

el_universal['host']= el_universal['url'].apply(lambda url: urlparse(url).netloc)

el_universal
# Out:
#                                                   body  \
# 0    \nLa procuradora Ernestina Godoy confirmó que ...
# 1                                                  NaN
# 2                                                  NaN
# 3    \n\nTras el triunfo de Barbosa y la derrota de...
# 4    \n\nLa noticia de que las niñas y niños de la ...
# ..                                                 ...
# 194  \nCDMX.- Cerca de las 18:30 horas, un hombre d...
# 195  \nTexto: Aída Castro SánchezDiseño web: Miguel...
# 196  \nTingüindín, Michoacán.- Diego Vidal Manzo, s...
# 197                                                NaN
# 198                                                NaN
#
#                                                  title  \
# 0    Matan a exdiputado de Tláhuac; investigan vínc...
# 1                                                  NaN
# 2                                                  NaN
# 3    Puebla: un tropiezo electoral no es una derrot...
# ...

# %%
el_universal['host'].value_counts()
# Out:
# www.eluniversal.com.mx             115
# www.elbotiquin.mx                    9
# www.viveusa.mx                       9
# bit.ly                               8
# www.tangible-eluniversal.com.mx      7
#                                   ...
# www.unionguanajuato.mx               1
# www.unionedomex.mx                   1
# interactivo.eluniversal.com.mx       1
# www.unionyucatan.mx                  1
# twitter.com                          1
# Name: host, Length: 22, dtype: int64

# %% [markdown]
# <h1>Missing data</h1>

# %%
# 3. Rellenar datos faltantes

missing_titles_mask = el_universal['title'].isna()

missing_titles= (el_universal[missing_titles_mask]['url']
                    .str.extract(r'(?P<missing_titles>[^/]+)$')
                    .astype(str).applymap(lambda title: title.replace('-', ' '))
                )
missing_titles
# Out:
#                                                                      missing_titles
# uid
# cb18691c58018e4163d72b0ed8bbcf38                                                box
# cf5bc6c8b4056dc4120a47d67699919e  en verdad padecio sifilis schubert el gran com...
# ea90d86c2113e6364b955ce4d1a86f78  ladron se dispara durante asalto pizzeria en m...
# c6c43c53fd8ad4c0b31f09d022dd168b  las bacterias que viven en tu celular y otros ...
# 1b5e6bc6261b96616dc9e98f51bcd8b1                                            2jmdiXT
# ...                                                                             ...
# 9e7dc9809e15c4ca776a868dc0aece1b  10 famosos que lucen irreconocibles con unos k...
# 3e542ff3beadc7730bbe798190f3cf39                                      suscripciones
# 481ff64955ad725df74ae0cc6913bd57                                            1TWQKcr
# ede25de0c732442cd78c6cb15327beec             6 ejercicios para tonificar los brazos
# ...

# %%
el_universal.loc[missing_titles_mask, 'title'] = missing_titles.loc[: , 'missing_titles']

# %% [markdown]
# <h1>Additional cleanup</h1>

# %%
# 4. añadir uid a las filas
import hashlib

uids = (el_universal
            .apply(lambda row: hashlib.md5(bytes(row['url'].encode())) ,axis=1)
            .apply(lambda hash_object: hash_object.hexdigest())
        )

el_universal['uid'] = uids
el_universal.set_index('uid', inplace=True)

el_universal
# Out:
#                                                                                body  \
# uid
# 6c7bf68194a8a5998597239b29be7e41  \nLa procuradora Ernestina Godoy confirmó que ...
# cb18691c58018e4163d72b0ed8bbcf38                                                NaN
# cf5bc6c8b4056dc4120a47d67699919e                                                NaN
# 35e6ddcb6722ef46c2f60a04d4e33229  \n\nTras el triunfo de Barbosa y la derrota de...
# 217d524b953cf2f3dabfe160622cc128  \n\nLa noticia de que las niñas y niños de la ...
# ...                                                                             ...
# 3486e1b91f94db6ad09d8d3dbef782e2  \nCDMX.- Cerca de las 18:30 horas, un hombre d...
# 0b3554fa7bcb1999372a959a34bcab22  \nTexto: Aída Castro SánchezDiseño web: Miguel...
# fef05cb73c5ba11f41aa58190726ca5a  \nTingüindín, Michoacán.- Diego Vidal Manzo, s...
# ab3f9d29135096228449397395057c36                                                NaN
# ...

# %%
stripped_body = (el_universal
                     .apply(lambda row: row['body'], axis=1) 
                     .astype(str).apply(lambda body: list(body))
                     .apply(lambda letters: list(map(lambda letter: letter.replace('\n', ''),letters)))
                     .apply(lambda letters: ''.join(letters))
                )

stripped_body
# Out:
# uid
# 6c7bf68194a8a5998597239b29be7e41    La procuradora Ernestina Godoy confirmó que el...
# cb18691c58018e4163d72b0ed8bbcf38                                                  nan
# cf5bc6c8b4056dc4120a47d67699919e                                                  nan
# 35e6ddcb6722ef46c2f60a04d4e33229    Tras el triunfo de Barbosa y la derrota de Cár...
# 217d524b953cf2f3dabfe160622cc128    La noticia de que las niñas y niños de la Ciud...
#                                                           ...
# 3486e1b91f94db6ad09d8d3dbef782e2    CDMX.- Cerca de las 18:30 horas, un hombre de ...
# 0b3554fa7bcb1999372a959a34bcab22    Texto: Aída Castro SánchezDiseño web: Miguel Á...
# fef05cb73c5ba11f41aa58190726ca5a    Tingüindín, Michoacán.- Diego Vidal Manzo, sub...
# ab3f9d29135096228449397395057c36                                                  nan
# dcdefeba6e4c6905af58a3b68f8bee94                                                  nan
# Length: 199, dtype: object

# %% [markdown]
# <h1>Data enrichment</h1>

# %%
# 6. tokenizar el titulo y el body 
import nltk
from nltk.corpus import stopwords

#nltk.download('punkt')
#nltk.download('stopwords')

stop_words = set(stopwords.words('spanish'))

def tokenize_column(df, column_name):
    return (df
               .dropna()
               .apply(lambda row: nltk.word_tokenize(row[column_name]), axis=1)
               .apply(lambda tokens: list(filter(lambda token: token.isalpha(), tokens )))
               .apply(lambda tokens: list(map(lambda token: token.lower(),tokens)))
               .apply(lambda word_list: list(filter(lambda word: word not in stop_words , word_list)))
               .apply(lambda valid_word_list: len(valid_word_list))
            )

el_universal['n_tokens_body'] = tokenize_column(el_universal, 'body')
el_universal
# Out:
#                                                                                body  \
# uid
# 6c7bf68194a8a5998597239b29be7e41  \nLa procuradora Ernestina Godoy confirmó que ...
# cb18691c58018e4163d72b0ed8bbcf38                                                NaN
# cf5bc6c8b4056dc4120a47d67699919e                                                NaN
# 35e6ddcb6722ef46c2f60a04d4e33229  \n\nTras el triunfo de Barbosa y la derrota de...
# 217d524b953cf2f3dabfe160622cc128  \n\nLa noticia de que las niñas y niños de la ...
# ...                                                                             ...
# fefe2a7902716da5e068e6a55171d7a0  \nFelipe Orocuta, boxeador mexicano, está sien...
# 3486e1b91f94db6ad09d8d3dbef782e2  \nCDMX.- Cerca de las 18:30 horas, un hombre d...
# 0b3554fa7bcb1999372a959a34bcab22  \nTexto: Aída Castro SánchezDiseño web: Miguel...
# fef05cb73c5ba11f41aa58190726ca5a  \nTingüindín, Michoacán.- Diego Vidal Manzo, s...
# ...

# %% [markdown]
# <h1>Duplicate values</h1>

# %%
# 8. Eliminar duplicados

el_universal['title'].value_counts()
# Out:
# Vicente Fernández suma nueva enemiga                                                  2
# Ámsterdam ofrece casarte por un día con un holandés para explorar la ciudad           2
# Cinco siglos del idioma español en México                                             2
# Trump frena aranceles con pacto migratorio                                            2
# La ex reina que ligó a crack de Chivas                                                2
#                                                                                      ..
# Mujeres buchonas, su vida de excesos: FOTOS                                           1
# "Nos falta Norberto"... así fue la foto de generación por su compañero secuestrado    1
# Iniciará operaciones la terminal de autobuses en el AIQ                               1
# “Hagan todo lo posible para encontrar a Norberto con vida”                            1
# 2bS1A5W                                                                               1
# ...

# %%
el_universal[el_universal['title'] == 'Vicente Fernández suma nueva enemiga']
# Out:
#                                                                                body  \
# uid
# 5b777e6eb648c54d4f51017ed7f7c6db  Lejos de calmar la polémica desatada por los c...
# bb3cbe2143052bed76415d54f955028f  Lejos de calmar la polémica desatada por los c...
#
#                                                                  title  \
# uid
# 5b777e6eb648c54d4f51017ed7f7c6db  Vicente Fernández suma nueva enemiga
# bb3cbe2143052bed76415d54f955028f  Vicente Fernández suma nueva enemiga
#
#                                                                                 url  \
# uid
# 5b777e6eb648c54d4f51017ed7f7c6db  http://www.unionjalisco.mx/articulo/2019/06/07...
# bb3cbe2143052bed76415d54f955028f  http://www.unionjalisco.mx/articulo/2019/06/07...
#
#                                  newspaper_uid                 host  \
# uid
# 5b777e6eb648c54d4f51017ed7f7c6db   eluniversal  www.unionjalisco.mx
# bb3cbe2143052bed76415d54f955028f   eluniversal  www.unionjalisco.mx
#
# ...

# %%
el_universal.drop_duplicates(subset=['title'], keep='first' , inplace=True)

# %% [markdown]
# <h1>Final Table</h1>

# %%
el_universal
# Out:
#                                                                                body  \
# uid
# 6c7bf68194a8a5998597239b29be7e41  \nLa procuradora Ernestina Godoy confirmó que ...
# cb18691c58018e4163d72b0ed8bbcf38                                                NaN
# cf5bc6c8b4056dc4120a47d67699919e                                                NaN
# 35e6ddcb6722ef46c2f60a04d4e33229  \n\nTras el triunfo de Barbosa y la derrota de...
# 217d524b953cf2f3dabfe160622cc128  \n\nLa noticia de que las niñas y niños de la ...
# ...                                                                             ...
# fefe2a7902716da5e068e6a55171d7a0  \nFelipe Orocuta, boxeador mexicano, está sien...
# 3486e1b91f94db6ad09d8d3dbef782e2  \nCDMX.- Cerca de las 18:30 horas, un hombre d...
# 0b3554fa7bcb1999372a959a34bcab22  \nTexto: Aída Castro SánchezDiseño web: Miguel...
# fef05cb73c5ba11f41aa58190726ca5a  \nTingüindín, Michoacán.- Diego Vidal Manzo, s...
# ...

# %%
clean_eluniversal = pd.read_csv('web_scrapper_curso_data_eng/clean_eluniversal_2019_06_07_articles.csv')
clean_eluniversal
# Out:
#                                   uid  \
# 0    6c7bf68194a8a5998597239b29be7e41
# 1    cb18691c58018e4163d72b0ed8bbcf38
# 2    cf5bc6c8b4056dc4120a47d67699919e
# 3    35e6ddcb6722ef46c2f60a04d4e33229
# 4    217d524b953cf2f3dabfe160622cc128
# ..                                ...
# 187  fefe2a7902716da5e068e6a55171d7a0
# 188  3486e1b91f94db6ad09d8d3dbef782e2
# 189  0b3554fa7bcb1999372a959a34bcab22
# 190  fef05cb73c5ba11f41aa58190726ca5a
# 191  ab3f9d29135096228449397395057c36
#
#                                                   body  \
# 0     La procuradora Ernestina Godoy confirmó que e...
# 1                                                  NaN
# 2                                                  NaN
# 3      Tras el triunfo de Barbosa y la derrota de C...
# 4      La noticia de que las niñas y niños de la Ci...
# ..                                                 ...
# 187   Felipe Orocuta, boxeador mexicano, está siend...
# ...

# %%
el_universal.describe()
# Out:
#        n_tokens_title  n_tokens_body
# count      109.000000     109.000000
# mean         5.302752     324.302752
# std          1.560535     315.938769
# min          2.000000      46.000000
# 25%          4.000000     122.000000
# 50%          5.000000     233.000000
# 75%          6.000000     395.000000
# max         10.000000    2267.000000

# %%
# %matplotlib inline

# %%
el_universal['n_tokens_title'].plot(style='k.')
